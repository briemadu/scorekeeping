# %% [markdown]
# # Human annotation and comparison to A's and Q's performance

# %%
import csv
import numpy as np
import pandas as pd
from pathlib import Path
import pickle
import json

from itertools import product, combinations
from nltk.metrics import agreement
from sklearn.metrics import cohen_kappa_score

import evaluationaux as ev 
from tasks import get_task_labels

# %matplotlib inline
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 50)

# %%
PATH = '/project/brie/scripts_scorekeeping/'
VISDIAL = Path('generating_propositions', 'data', 'visual_dialog')
PROPS = Path(PATH, 'main_task', 'data', 'propositions')
PATH_OUTPUTS = Path(PATH, 'main_task', 'outputs')

# %%
path_visdial_test = Path(PATH, VISDIAL, 'visdial_1.0_test.json')
with open(path_visdial_test, 'r') as e:
    visdial_test = json.load(e)
    
path_props_test = Path(PATH, PROPS, 'propositions_test.json')
with open(path_props_test, 'r') as f:
    props_test = json.load(f)['dialogues']

# %%
SPLIT = 'test'

BOTS =  ('a', 'q')
CONTROL_TASKS =  ('none', 'rand-reps', 'null-reps')
TASKS =  ('TFxPS', 'TF', 'PS', 'PxTSFS')
BOT_VERSIONS =  ('RL-DIV', 'SL', 'ICCV-RL')

# %%
df = pd.read_csv('human-results/human-results.csv')
df.shape
# Out:
# (300, 17)

# %% [markdown]
# 300 because the original sample had 100 (dialogue, proposition, turn shown) triples annotated by 3 students.

# %% [markdown]
# These six cases were removed/edited on the final test set and will be excluded (see filtering_probes.ipynb):

# %%
EXCLUDED = (14, 1310, 7054, 7417, 798, 6447)

annot_df = df[~df['dlg_idx'].isin(EXCLUDED)].copy()
annot_df.shape
# Out:
# (282, 17)

# %% [markdown]
# So the used sample has 94 datapoints, 300-(6*3) = 282.

# %% [markdown]
# **Important**: remember that, on this dataframe, content=1 means true and shared=1 means shared. It was reversed in the labels created for training, so a direct comparison should take that into account. To avoid confusion, the cell below will create new columns using the same labels used in training.

# %%
for task in TASKS:
    classes, classes_names = get_task_labels(bot='a', task=task)
    annot_df[task + '_gold'] = annot_df.apply(lambda row: classes[(row.content_gold, row.shared_gold)], axis=1)
    annot_df[task + '_pred'] = annot_df.apply(lambda row: classes[(row.content, row.shared)], axis=1)

# check if correct prediction in TF dimension
annot_df['TF_isright'] = (annot_df['content'] == annot_df['content_gold']) 
# check if correct prediction in PS dimension
annot_df['PS_isright'] = (annot_df['shared'] == annot_df['shared_gold']) 
# check if correct prediction in both dimensions
annot_df['TFxPS_isright'] = (annot_df['TF_isright'] & annot_df['PS_isright']) 
# check if correct prediction in PxTSFS dimension
annot_df['PxTSFS_isright'] = (annot_df['PxTSFS_pred'] == annot_df['PxTSFS_gold'])

annot_df['TF_isright_v2'] = (annot_df['TF_pred'] == annot_df['TF_gold'])
annot_df['PS_isright_v2'] = (annot_df['PS_pred'] == annot_df['PS_gold']) 
annot_df['TFxPS_isright_v2'] = (annot_df['TFxPS_pred'] == annot_df['TFxPS_gold'])

# %% [markdown]
# Ensuring that created classes using two methods lead to same results (i.e. the apply method is working):

# %%
assert annot_df['TFxPS_isright'].equals(annot_df['TFxPS_isright_v2'])
assert annot_df['TF_isright'].equals(annot_df['TF_isright_v2'])
assert annot_df['PS_isright'].equals(annot_df['PS_isright_v2'])

# %%
annot_df
# Out:
# 120   L587OV  16:41:52  test     3755         2        11        0
# 121   L587OV  16:42:13  test     2899         1         1        0
# 122   L587OV  16:43:02  test     2456         6        20        1
# 123   L587OV  16:43:16  test     4022         0         1        0
# 124   L587OV  16:44:46  test     2897         4         6        1
# 125   L587OV  16:45:17  test       61         0         4        1
# 126   L587OV  16:46:06  test     1242         6         5        0
# 127   L587OV  16:46:33  test     7683         0         2        1
# 129   L587OV  16:48:59  test     7775         4        13        0
# 130   L587OV  16:49:37  test     7520         0         6        1
# 131   L587OV  16:50:23  test     5944         1        16        1
# 132   L587OV  16:50:49  test     2397         1         2        1
# 134   L587OV  16:51:40  test     7246         4        11        0
# 135   L587OV  16:52:20  test     5164         4        13        0
# 136   L587OV  16:52:44  test     2434         1        10        1
# 138   L587OV  16:54:23  test     4396         2         6        1
# 139   L587OV  16:54:54  test      639         0         6        1
# 140   L587OV  16:55:32  test     1161         2         3        0
# 141   L587OV  16:55:59  test      470         3         9        1
# 142   L587OV  16:58:33  test     4953         5        11        0
# 143   L587OV  16:58:45  test      111         0         5        0
# 144   L587OV  16:59:15  test     5950         2        11        0
# 145   L587OV  16:59:44  test     5102         2        12        1
# 146   L587OV  17:00:09  test     7056         0         8        1
# 147   L587OV  17:12:44  test     2446         2        12        1
# 148   L587OV  17:13:00  test     6058         1         7        0
# 149   L587OV  17:13:22  test     6665         0        13        0
# 150   L587OV  17:13:54  test     4718         1         6        1
# 151   L587OV  17:14:36  test     4799         4         1        0
# 152   L587OV  17:14:59  test     2680         4         0        1
# 153   L587OV  17:15:35  test      344         8        20        1
# 154   L587OV  17:16:14  test     3610         2        19        0
# 156   L587OV  17:17:27  test     3454         4         8        1
# 157   L587OV  17:17:52  test      397         6         6        1
# 158   L587OV  17:18:06  test      333         0         3        0
# 159   L587OV  17:18:22  test     7530         0        10        0
# 160   L587OV  17:19:03  test     4848         3         5        0
# 161   L587OV  17:19:30  test     7052         2        10        1
# 162   L587OV  17:19:54  test     4136         0         0        1
# 163   L587OV  17:20:15  test     6298         1         8        1
# 164   L587OV  17:20:39  test     5176         0         4        1
# 165   L587OV  17:20:50  test     3094         0        11        0
# 166   L587OV  17:21:20  test     3865         1        11        0
# 167   L587OV  17:21:54  test      195         2        15        0
# 168   L587OV  17:23:46  test     3497         2         7        0
# 169   L587OV  17:24:07  test     4475         2        12        1
# 170   L587OV  17:24:35  test     4448         1         6        1
# 171   L587OV  17:26:17  test     5493         9        22        1
# 172   L587OV  17:27:11  test     4695         1        12        1
# 174   L587OV  17:27:42  test     1571         1         8        1
# 175   L587OV  17:28:05  test      802         0         7        0
# 176   L587OV  17:28:21  test     7302         6        19        0
# 177   L587OV  17:28:51  test     4005         0         8        1
# 178   L587OV  17:29:00  test     6149         0         5        0
# 179   L587OV  17:29:18  test     3483         7        17        0
# 180   L587OV  17:29:39  test     3052         1         9        0
# 181   L587OV  17:29:51  test     5199         0         5        0
# 182   L587OV  17:30:34  test      985         1         5        0
# 183   L587OV  17:30:58  test     3969         0         5        0
# 184   L587OV  17:31:14  test     6720         0         5        0
# 185   L587OV  17:31:39  test     1477         0         4        1
# 14              1       0            0            3     is_noun_adj
# 15              1       1            1            7            any_
# 16              0       0            0            2        look_adj
# 17              1       1            1            0         caption
# 18              0       0            0            8      what_color
# 19              0       1            1            2      what_color
# 20              1       0            0            1      what_color
# 21              0       1            1            8       noun_verb
# 22              1       1            1            0         caption
# 23              1       0            0            8     can_you_see
# 25              1       1            1            5         daytime
# 26              1       0            0            3           there
# 27              1       0            0            1           there
# 28              1       1            0            3           there
# 30              0       1            1            1  image_in_color
# 31              1       0            0            4     can_you_see
# 32              0       0            0            2     can_you_see
# 33              1       0            0            2       noun_noun
# 34              1       0            0            3        look_adj
# 35              1       0            0            4     can_you_see
# 36              0       1            1            3           there
# 37              1       0            0            1           is_it
# 38              0       0            1            0         caption
# 39              1       1            1            0         caption
# 40              0       1            1            2            any_
# 41              1       1            1            3      what_color
# 42              0       0            0            2           there
# 43              1       1            1            0         caption
# 44              0       1            1            0         caption
# 45              1       1            1            9     can_you_see
# 46              0       1            1            0         caption
# 47              0       1            1            1           sunny
# 48              1       0            0            8            any_
# 49              1       1            1            1       noun_verb
# 50              0       1            1            0         caption
# 51              1       0            0            3      what_color
# 52              0       0            0            8           there
# 53              0       0            0            7  noun_prep_noun
# 54              0       1            1            4           sunny
# 55              1       1            1            1      what_color
# 56              0       1            1            2      what_color
# 57              0       0            0            5      what_color
# 58              1       0            0            4           there
# 59              1       0            0            4           there
# 60              0       0            0            2       noun_noun
# 61              0       1            1            1      what_color
# 62              0       0            1            0         caption
# 63              0       0            0            3            any_
# 64              1       1            1            8       noun_noun
# 66              1       1            1            1     can_you_see
# 67              1       0            0            6        look_adj
# 68              0       1            1            2        look_adj
# 69              0       0            0            6           there
# 70              0       1            1            4     is_noun_adj
# 71              1       0            0            6           there
# 72              0       1            1            3     can_you_see
# 73              1       1            1            1         weather
# 74              0       1            1            0         caption
# 75              1       0            1            0         caption
# 77              0       1            1            2     is_noun_adj
# 78              0       1            1            0         caption
# 79              1       0            0            2      what_color
# 80              0       1            1            0         caption
# 81              1       0            0            4      what_color
# 82              1       0            0            3           there
# 83              1       0            0            4            any_
# 84              1       1            1            0         caption
# 85              0       1            1            1      what_color
# 86              1       1            1            1     is_noun_adj
# 87              1       0            0            1        is_np_np
# 88              0       1            1            5           there
# 89              0       1            1            0         caption
# 90              1       1            1            4       noun_verb
# 91              0       0            0            4            any_
# 92              1       1            1            0         caption
# 94              0       0            0            4     can_you_see
# 95              1       1            1            6       noun_verb
# 96              0       1            1            4           noun_
# 97              0       1            1            2         what_is
# 98              1       0            0            1      adj_or_adj
# 99              0       1            1            5     can_you_see
# 100             1       1            1            3      what_color
# 101             0       1            1            5           there
# 102             1       1            1            0         caption
# 103             1       1            1            6       noun_verb
# 104             0       1            1            1      what_color
# 105             1       1            1            5         daytime
# 106             1       0            0            8            any_
# 107             0       1            1            1  image_in_color
# 108             0       0            0            2       noun_noun
# 109             0       1            1            2     is_noun_adj
# 110             1       0            0            4           there
# 111             0       1            1            0         caption
# 112             0       1            1            1      what_color
# 113             1       0            0            6        look_adj
# 114             0       1            1            2      what_color
# 115             0       0            0            8           there
# 116             1       1            1            0         caption
# 224             1       1            1            0         caption
# 225             0       1            1            8       noun_verb
# 226             0       0            0            5      what_color
# 227             0       0            0            8           there
# 228             0       1            1            0         caption
# 230             0       1            1            0         caption
# 231             1       0            0            2      what_color
# 232             1       0            0            1           there
# 234             1       0            0            1           is_it
# 235             0       1            1            2         what_is
# 236             1       0            0            3     is_noun_adj
# 237             1       0            0            4      what_color
# 238             0       0            0            1           there
# 239             0       0            0            6           there
# 240             1       0            0            8     can_you_see
# 241             1       0            0            1      what_color
# 242             1       0            0            2       noun_noun
# 243             0       1            1            2      what_color
# 244             0       1            1            4           noun_
# 245             0       1            1            5           there
# 246             1       0            0            2      what_color
# 248             0       1            1            4     is_noun_adj
# 249             1       1            1            4       noun_verb
# 250             1       0            0            6        look_adj
# 251             1       1            1            6       noun_verb
# 252             1       0            0            4           there
# 253             0       1            1            1  image_in_color
# 254             1       1            1            0         caption
# 255             0       1            1            0         caption
# 256             0       1            1            3     can_you_see
# 257             0       0            0            7  noun_prep_noun
# 258             1       0            0            2           there
# 259             0       0            0            4     can_you_see
# 260             1       0            0            8            any_
# 261             1       1            1            9     can_you_see
# 262             0       0            1            0         caption
# 263             0       0            0            4            any_
# 264             1       0            0            6           there
# 265             0       1            1            5     can_you_see
# 266             0       1            1            3           there
# 267             1       1            1            0         caption
# 268             1       0            0            3      what_color
# 269             1       0            0            4     can_you_see
# 270             1       1            1            1     can_you_see
# 271             0       0            0            8      what_color
# 272             1       0            0            1           there
# 273             1       0            0            4            any_
# 274             0       1            1            0         caption
# 275             0       0            0            2       noun_noun
# 276             1       1            1            0         caption
# 277             0       1            1            1           sunny
# 278             0       1            0            4           noun_
# 279             0       1            1            1      what_color
# 280             1       1            1            0         caption
# 281             0       1            1            1      what_color
# 282             0       1            1            0         caption
# 283             0       1            1            2        look_adj
# 284             1       0            0            3           there
# 285             1       1            1            1      what_color
# 286             1       1            1            8       noun_noun
# 287             0       0            0            3           there
# 288             0       0            0            3            any_
# 289             0       0            0            2           there
# 290             1       0            0            3           there
# 291             1       1            1            0         caption
# 292             1       0            0            1      what_color
# 293             0       1            1            0         caption
# 294             0       1            1            2      what_color
# 295             0       1            1            2     is_noun_adj
# 296             1       1            1            1     is_noun_adj
# 298             1       1            1            0         caption
# 299             1       1            1            3      what_color
#
#                      type   qa_fact  \
# 0       direct entailment      none
# 1       direct entailment  positive
# 2    direct contradiction      none
# 3    direct contradiction  negative
# 4    direct contradiction  negative
# 5       direct entailment      none
# 6    direct contradiction      none
# 7    direct contradiction  positive
# 8    direct contradiction  negative
# 10      direct entailment      none
# 11      direct entailment      none
# 12      direct entailment  negative
# 13      direct entailment  positive
# 14      direct entailment  positive
# 15      direct entailment  negative
# 16   direct contradiction  positive
# 17      direct entailment      none
# 18   direct contradiction      none
# 19   direct contradiction      none
# 20      direct entailment      none
# 21   direct contradiction  negative
# 22      direct entailment      none
# 23      direct entailment  positive
# 25      direct entailment  positive
# 26      direct entailment  negative
# 27      direct entailment  positive
# 28      direct entailment  negative
# 30   direct contradiction  positive
# 31      direct entailment  negative
# 32   direct contradiction  negative
# 33      direct entailment  negative
# 34      direct entailment  positive
# 35      direct entailment  positive
# 36   direct contradiction  positive
# 37      direct entailment  positive
# 38   direct contradiction      none
# 39      direct entailment      none
# 40   direct contradiction  negative
# 41      direct entailment      none
# 42   direct contradiction  negative
# 43      direct entailment      none
# 44   direct contradiction      none
# 45      direct entailment  negative
# 46   direct contradiction      none
# 47   direct contradiction  negative
# 48      direct entailment  negative
# 49      direct entailment  positive
# 50   direct contradiction      none
# 51      direct entailment      none
# 52   direct contradiction  negative
# 53   direct contradiction  positive
# 54   direct contradiction  positive
# 55      direct entailment      none
# 56   direct contradiction      none
# 57   direct contradiction      none
# 58      direct entailment  positive
# 59      direct entailment  negative
# 60   direct contradiction  positive
# 61   direct contradiction      none
# 62   direct contradiction      none
# 63   direct contradiction  negative
# 64      direct entailment  negative
# 66      direct entailment  negative
# 67      direct entailment  positive
# 68   direct contradiction  negative
# 69   direct contradiction  negative
# 70   direct contradiction  positive
# 71      direct entailment  negative
# 72   direct contradiction  negative
# 73      direct entailment      none
# 74   direct contradiction      none
# 75      direct entailment      none
# 77   direct contradiction  positive
# 78   direct contradiction      none
# 79      direct entailment      none
# 80   direct contradiction      none
# 81      direct entailment      none
# 82      direct entailment  positive
# 83      direct entailment  negative
# 84      direct entailment      none
# 85   direct contradiction      none
# 86      direct entailment  negative
# 87      direct entailment  negative
# 88   direct contradiction  positive
# 89   direct contradiction      none
# 90      direct entailment  positive
# 91   direct contradiction  positive
# 92      direct entailment      none
# 94   direct contradiction  negative
# 95      direct entailment  positive
# 96   direct contradiction  positive
# 97   direct contradiction      none
# 98      direct entailment      none
# 99   direct contradiction  negative
# 100     direct entailment      none
# 101  direct contradiction  positive
# 102     direct entailment      none
# 103     direct entailment  positive
# 104  direct contradiction      none
# 105     direct entailment  positive
# 106     direct entailment  negative
# 107  direct contradiction  positive
# 108  direct contradiction  positive
# 109  direct contradiction  positive
# 110     direct entailment  positive
# 111  direct contradiction      none
# 112  direct contradiction      none
# 113     direct entailment  positive
# 114  direct contradiction      none
# 115  direct contradiction  negative
# 116     direct entailment      none
# 117  direct contradiction      none
# 118     direct entailment      none
# 119     direct entailment  positive
# 120  direct contradiction      none
# 121  direct contradiction      none
# 122     direct entailment  positive
# 123  direct contradiction      none
# 124     direct entailment      none
# 125     direct entailment  negative
# 126  direct contradiction  positive
# 127     direct entailment      none
# 129  direct contradiction  positive
# 130     direct entailment      none
# 131     direct entailment  negative
# 132     direct entailment      none
# 134  direct contradiction  negative
# 135  direct contradiction  positive
# 136     direct entailment  negative
# 138     direct entailment      none
# 139     direct entailment      none
# 140  direct contradiction      none
# 141  direct contradiction      none
# 142  direct contradiction  positive
# 143  direct contradiction      none
# 144  direct contradiction      none
# 145     direct entailment      none
# 146     direct entailment  positive
# 147     direct entailment  positive
# 148  direct contradiction  negative
# 149  direct contradiction  negative
# 150     direct entailment      none
# 151  direct contradiction      none
# 152     direct entailment      none
# 153     direct entailment  negative
# 154  direct contradiction  negative
# 156     direct entailment  negative
# 157     direct entailment  positive
# 158  direct contradiction      none
# 159     direct entailment  negative
# 160  direct contradiction  negative
# 161     direct entailment  negative
# 162     direct entailment      none
# 163     direct entailment  negative
# 164     direct entailment      none
# 165  direct contradiction  negative
# 166  direct contradiction  positive
# 167  direct contradiction  negative
# 168  direct contradiction      none
# 169     direct entailment  positive
# 170     direct entailment      none
# 171     direct entailment  negative
# 172     direct entailment  positive
# 174     direct entailment  negative
# 175  direct contradiction      none
# 176  direct contradiction  negative
# 177     direct entailment  negative
# 178  direct contradiction      none
# 179  direct contradiction  negative
# 180  direct contradiction  negative
# 181  direct contradiction      none
# 182  direct contradiction  negative
# 183  direct contradiction  positive
# 184  direct contradiction  negative
# 185     direct entailment      none
# 186     direct entailment  positive
# 187     direct entailment  negative
# 188  direct contradiction  positive
# 189     direct entailment  positive
# 190  direct contradiction  negative
# 191     direct entailment      none
# 193  direct contradiction  negative
# 194     direct entailment      none
# 195     direct entailment  negative
# 196     direct entailment  negative
# 197     direct entailment  positive
# 198  direct contradiction  positive
# 199     direct entailment  positive
# 202     direct entailment      none
# 203     direct entailment  positive
# 204  direct contradiction  negative
# 205     direct entailment  positive
# 206     direct entailment  negative
# 207     direct entailment      none
# 208  direct contradiction      none
# 209     direct entailment      none
# 210  direct contradiction  negative
# 211  direct contradiction      none
# 212     direct entailment  negative
# 213     direct entailment  negative
# 214     direct entailment  negative
# 215     direct entailment  positive
# 216  direct contradiction  positive
# 217  direct contradiction      none
# 218     direct entailment  positive
# 219  direct contradiction  negative
# ...
# 234        True        True           True            True           True
# 235        True        True           True            True           True
# 236        True        True           True            True           True
# 237        True        True           True            True           True
# 238        True        True           True            True           True
# 239        True        True           True            True           True
# 240        True        True           True            True           True
# 241        True        True           True            True           True
# 242       False        True          False            True          False
# 243        True        True           True            True           True
# 244        True        True           True            True           True
# 245        True        True           True            True           True
# 246       False        True          False            True          False
# 248       False        True          False           False          False
# 249        True        True           True            True           True
# 250       False        True          False            True          False
# 251        True        True           True            True           True
# 252       False        True          False            True          False
# 253        True        True           True            True           True
# 254        True        True           True            True           True
# 255        True        True           True            True           True
# 256        True        True           True            True           True
# 257        True        True           True            True           True
# 258        True        True           True            True           True
# 259        True        True           True            True           True
# 260        True        True           True            True           True
# 261        True        True           True            True           True
# 262        True       False          False           False           True
# 263        True        True           True            True           True
# 264        True        True           True            True           True
# 265        True        True           True            True           True
# 266        True        True           True            True           True
# 267        True        True           True            True           True
# 268        True        True           True            True           True
# 269        True        True           True            True           True
# 270        True        True           True            True           True
# 271        True        True           True            True           True
# 272        True        True           True            True           True
# 273        True        True           True            True           True
# 274        True        True           True            True           True
# 275        True        True           True            True           True
# 276        True        True           True            True           True
# 277        True        True           True            True           True
# 278        True       False          False           False           True
# 279        True        True           True            True           True
# 280        True        True           True            True           True
# 281        True        True           True            True           True
# 282        True        True           True            True           True
# 283        True        True           True            True           True
# 284       False        True          False            True          False
# 285        True        True           True            True           True
# 286        True        True           True            True           True
# 287        True        True           True            True           True
# 288        True        True           True            True           True
# 289        True        True           True            True           True
# 290        True        True           True            True           True
# 291        True        True           True            True           True
# 292        True        True           True            True           True
# 293        True        True           True            True           True
# 294        True        True           True            True           True
# 295        True        True           True            True           True
# 296        True        True           True            True           True
# 298        True        True           True            True           True
# 299        True        True           True            True           True
#
#      PS_isright_v2  TFxPS_isright_v2
# 0             True              True
# 1             True              True
# 2             True              True
# 3             True              True
# 4             True              True
# 5             True             False
# 6             True              True
# 7             True             False
# 8             True              True
# 10            True              True
# 11            True              True
# 12            True              True
# 13            True              True
# 14            True              True
# 15            True              True
# 16            True              True
# 17            True              True
# 18            True              True
# 19            True              True
# 20            True              True
# 21            True              True
# 22            True              True
# 23            True              True
# 25            True              True
# 26            True              True
# 27            True              True
# 28           False             False
# 30            True              True
# 31            True              True
# 32            True              True
# 33            True             False
# 34            True              True
# 35            True              True
# 36            True              True
# 37            True              True
# 38           False             False
# 39            True              True
# 40            True              True
# 41            True              True
# 42            True              True
# 43            True              True
# 44            True              True
# 45            True              True
# 46            True              True
# 47            True              True
# 48            True              True
# 49            True              True
# 50            True              True
# 51            True              True
# 52            True              True
# 53            True              True
# 54            True              True
# 55            True              True
# 56            True              True
# 57            True              True
# 58            True              True
# 59            True              True
# 60            True              True
# 61            True              True
# 62           False             False
# 63            True              True
# 64            True              True
# 66            True              True
# 67            True             False
# 68            True              True
# 69            True              True
# 70            True              True
# 71            True              True
# 72            True              True
# 73            True              True
# 74            True              True
# 75           False             False
# 77            True              True
# 78            True              True
# 79            True              True
# 80            True              True
# 81            True              True
# 82            True              True
# 83            True              True
# 84            True              True
# 85            True              True
# 86            True              True
# 87            True              True
# 88            True              True
# 89            True              True
# 90            True              True
# 91            True              True
# 92            True              True
# 94            True              True
# 95            True              True
# 96            True              True
# 97            True              True
# 98            True              True
# 99            True              True
# 100           True              True
# 101           True              True
# 102           True              True
# 103           True              True
# 104           True              True
# 105           True              True
# 106           True              True
# 107           True             False
# 108           True             False
# 109           True              True
# 110           True              True
# 111           True             False
# 112           True              True
# 113           True             False
# 114           True              True
# 115           True              True
# 116           True              True
# 117           True              True
# 118           True              True
# 119           True              True
# 120           True              True
# 121           True              True
# 122           True              True
# 123           True              True
# 124           True              True
# 125           True              True
# 126           True              True
# 127           True              True
# 129           True              True
# 130           True              True
# 131           True              True
# 132           True              True
# 134           True              True
# 135           True              True
# 136          False             False
# 138           True              True
# 139           True              True
# 140           True              True
# 141           True             False
# 142           True              True
# 143           True              True
# 144           True              True
# 145           True              True
# 146           True              True
# 147           True              True
# 148           True              True
# 149           True              True
# 150           True              True
# 151           True              True
# 152           True              True
# 153           True              True
# 154           True              True
# 156           True              True
# 157           True              True
# 158           True              True
# 159           True             False
# 160           True              True
# 161           True              True
# 162           True              True
# 163           True              True
# 164           True              True
# 165           True              True
# 166           True              True
# 167           True              True
# 168           True              True
# 169           True              True
# 170           True              True
# 171           True              True
# 172           True              True
# 174           True              True
# 175           True              True
# 176           True              True
# 177           True              True
# 178           True              True
# 179           True              True
# 180           True              True
# 181           True              True
# 182           True              True
# 183           True              True
# 184           True              True
# 185           True              True
# 186           True              True
# 187           True              True
# 188           True              True
# 189           True              True
# 190           True              True
# 191           True              True
# 193           True              True
# 194           True              True
# 195           True              True
# 196           True              True
# 197           True              True
# 198           True              True
# 199           True              True
# 202           True              True
# 203           True              True
# 204           True              True
# 205           True              True
# 206           True              True
# 207           True              True
# 208           True              True
# 209           True              True
# 210           True              True
# 211           True              True
# 212           True              True
# 213           True              True
# 214           True              True
# 215           True              True
# 216           True              True
# 217           True              True
# 218           True              True
# 219           True              True
# 220           True              True
# 221           True              True
# 222           True              True
# 223           True              True
# 224           True              True
# 225           True              True
# 226           True              True
# 227           True              True
# 228           True              True
# 230           True              True
# 231           True              True
# 232           True              True
# 234           True              True
# 235           True              True
# 236           True              True
# 237           True              True
# 238           True              True
# 239           True              True
# 240           True              True
# 241           True              True
# 242           True             False
# 243           True              True
# 244           True              True
# 245           True              True
# 246           True             False
# 248           True             False
# 249           True              True
# 250           True             False
# 251           True              True
# 252           True             False
# 253           True              True
# 254           True              True
# 255           True              True
# 256           True              True
# 257           True              True
# 258           True              True
# 259           True              True
# 260           True              True
# 261           True              True
# 262          False             False
# 263           True              True
# 264           True              True
# 265           True              True
# 266           True              True
# 267           True              True
# 268           True              True
# 269           True              True
# 270           True              True
# 271           True              True
# 272           True              True
# 273           True              True
# 274           True              True
# 275           True              True
# 276           True              True
# 277           True              True
# 278          False             False
# 279           True              True
# 280           True              True
# 281           True              True
# 282           True              True
# 283           True              True
# 284           True             False
# 285           True              True
# 286           True              True
# 287           True              True
# 288           True              True
# 289           True              True
# 290           True              True
# 291           True              True
# 292           True              True
# 293           True              True
# 294           True              True
# 295           True              True
# 296           True              True
# 298           True              True
# 299           True              True

# %%
human_sample = set([tuple(r) for r in annot_df.loc[:, ['dlg_idx', 'prop_idx', 'turn_shared', 'type']].to_numpy()])
assert len(human_sample) == 100 - len(EXCLUDED) # 94

# %% [markdown]
# ## Human results

# %%
USERS = list(set(annot_df['username']))

# %%
human_metrics = {task: {} for task in TASKS}

for i, user in enumerate(USERS):
    for task in TASKS:
        human_metrics[task][user] = 100 * np.mean(annot_df[annot_df['username'] == user][task + '_isright'])
    print(f'User {i+1}: {human_metrics["TF"][user]} on TF, {human_metrics["PS"][user]} on PS, {human_metrics["TFxPS"][user]} on TFxPS, {human_metrics["PxTSFS"][user]} on PxTSFS')
# Out:
# User 1: 93.61702127659575 on TF, 97.87234042553192 on PS, 91.48936170212765 on TFxPS, 96.80851063829788 on PxTSFS
# User 2: 93.61702127659575 on TF, 98.93617021276596 on PS, 92.5531914893617 on TFxPS, 95.74468085106383 on PxTSFS
# User 3: 95.74468085106383 on TF, 95.74468085106383 on PS, 91.48936170212765 on TFxPS, 95.74468085106383 on PxTSFS

# %%
table_df = pd.DataFrame(columns=TASKS)
values = []
for task in TASKS:
    mean = np.mean([human_metrics[task][u] for u in USERS])
    values.append(mean)
    print(f'Mean {task}: {mean}')

table_df.loc['human'] = values
# Out:
# Mean TFxPS: 91.84397163120566
# Mean TF: 94.32624113475178
# Mean PS: 97.51773049645391
# Mean PxTSFS: 96.09929078014186

# %% [markdown]
# Table for the paper:

# %%
table_df
# Out:
#            TFxPS         TF        PS     PxTSFS
# human  91.843972  94.326241  97.51773  96.099291

# %% [markdown]
# ## Inter-Annotator Agreement

# %% [markdown]
# Each datapoint in the sample comes form a different dialogue. So it has 94 dialogue ids, each annotated by 3 annotators.

# %%
assert len(set(annot_df["dlg_idx"].to_numpy())) == 100 - len(EXCLUDED)

# %%
IDS = list(set(annot_df["dlg_idx"].to_numpy()))
IDS.sort()
assert len(IDS) == 100 - len(EXCLUDED)

# %%
kappas = {task: {} for task in TASKS}
annotations = {task: {} for task in TASKS}

for task in TASKS:
    for (user_1, user_2) in combinations(USERS, 2):
        
        labels_1 = annot_df.loc[annot_df["username"] == user_1, ["dlg_idx", task + '_pred']].copy().sort_values(by=["dlg_idx"])
        labels_2 = annot_df.loc[annot_df["username"] == user_2, ["dlg_idx", task + '_pred']].copy().sort_values(by=["dlg_idx"])
        
        assert (labels_1['dlg_idx'].to_numpy() == labels_2['dlg_idx'].to_numpy()).all()
        
        annotations[task][user_1] = {dialogue: label for _, (dialogue, label) in labels_1.iterrows()}
        annotations[task][user_2] = {dialogue: label for _, (dialogue, label) in labels_2.iterrows()}
        
        labels_1 = labels_1[task + '_pred'].to_numpy()
        labels_2 = labels_2[task + '_pred'].to_numpy()

        kappa = cohen_kappa_score(labels_1, labels_2)
        kappas[task][(user_1, user_2)] = kappa
        print(f'{task}, {user_1} and {user_2}: {kappa}')

# another way to get the values, returns same results:
#print('\n')
#for task in TASKS:
#    for (user_1, user_2) in combinations(USERS, 2):
#        
#        df_1 = annot_df.loc[annot_df["username"] == user_1, ["dlg_idx", task + '_pred']]
#        df_2 = annot_df.loc[annot_df["username"] == user_2, ["dlg_idx", task + '_pred']]
#        
#        labels_1 = np.array([df_1.loc[df_1['dlg_idx'] == idx][task + '_pred'].item() for idx in IDS])
#        labels_2 = np.array([df_2.loc[df_2['dlg_idx'] == idx][task + '_pred'].item() for idx in IDS])
#
#        kappa = cohen_kappa_score(labels_1, labels_2)
#        kappas[task][(user_1, user_2)] = kappa
#        print(f'{task}, {user_1} and {user_2}: {kappa}')
# Out:
# TFxPS, EZTJJK and L587OV: 0.8287015945330296
# TFxPS, EZTJJK and PU6HR2: 0.9143897996357013
# TFxPS, L587OV and PU6HR2: 0.8428332573339413
# TF, EZTJJK and L587OV: 0.7880018042399639
# TF, EZTJJK and PU6HR2: 0.9148936170212766
# TF, L587OV and PU6HR2: 0.8297872340425532
# PS, EZTJJK and L587OV: 0.9352914180816888
# PS, EZTJJK and PU6HR2: 0.9143117593436645
# PS, L587OV and PU6HR2: 0.9356458238247376
# PxTSFS, EZTJJK and L587OV: 0.8852258852258852
# PxTSFS, EZTJJK and PU6HR2: 0.9171075837742504
# PxTSFS, L587OV and PU6HR2: 0.9011220196353437

# %%
n_sample = annot_df.shape[0] / 3

for task in TASKS:
    print(task)
    annotation_data = []
    for n, idx in enumerate(IDS):
        annotation_data.append((USERS[0], n, annotations[task][USERS[0]][idx]))
        annotation_data.append((USERS[1], n, annotations[task][USERS[1]][idx]))
        annotation_data.append((USERS[2], n, annotations[task][USERS[2]][idx]))
        
    annot_task = agreement.AnnotationTask(data=annotation_data)
    print("Cohen's Kappa:", annot_task.kappa())
    print("Fleiss's Kappa:", annot_task.multi_kappa())
# Out:
# TFxPS
# Cohen's Kappa: 0.861974883834224
# Fleiss's Kappa: 0.8619886593762657
# TF
# Cohen's Kappa: 0.8442275517679313
# Fleiss's Kappa: 0.8441597588545589
# PS
# Cohen's Kappa: 0.9284163337500303
# Fleiss's Kappa: 0.9283973187081049
# PxTSFS
# Cohen's Kappa: 0.9011518295451597
# Fleiss's Kappa: 0.9010931197755305

# %% [markdown]
# ## Compare to A and Q

# %% [markdown]
# Create set with all element ids in sample. First read the data:

# %%
test_outputs = {}
test_datapoints = {}
epoch = 0  # for the test set, the only inference step is saved as 0

# embs='pmbv2', model='Deeper' as default on ev.get_data

for (bot, task, version) in product(BOTS, TASKS, BOT_VERSIONS):
    if bot == 'q' and 'TF' in task:
        continue
    data, outputs = ev.get_data(bot, task, 'none', PATH_OUTPUTS, split=SPLIT, bot_version=version, epoch=0)
    
    # sanity check that loaded dataset contains same datapoints used in the experiments
    data_identifiers = ev.get_identifiers(bot, version, task, 'none', PATH_OUTPUTS, split=SPLIT)
    assert ev.compare_identifiers(data.datapoints, data_identifiers)
    
    test_outputs[(bot, task, version)] = outputs
    test_datapoints[(bot, task, version)] = data.datapoints

# %% [markdown]
# Make sure again that all datasets create the same datapoints for the same tasks:

# %%
for task in TASKS:
    task_datapoints = [v for k, v in test_datapoints.items() if k[1] == task]
    assert all(x == task_datapoints[0] for x in task_datapoints)

# %% [markdown]
# Get only the elements in the human sample. Because the prop_id may have changed on the final datasets, due to the SpaCy/Coref steps, we must confirm that the sentences are indeed the same (see filtering_probes.ipynb). For captions, we can (supposedly) rely on the proposition ID (we assert to be sure), because coref resolution is not used when generating caption propositions and the rules did not change. By using the same Spacy version, nothing should change. For the remaining rules, the prop_id is not reliable because by removing the ```how_many``` rule and with the new coref model, besides other small adjustments in the rules (```look_like```), their order may have changed. What persists is the triplet (dialogue_id, turn_shared, a_thinks_true).
#
# With all assertions passing, we create the sample with the new corresponding (dialogue_id, proposition_id) that is unique plus the turn up to which the dialogue was shown.

# %%
sample = []
before_to_after = {}

for _, row in annot_df.iterrows():
    
    if row.turn_shared == 0:
        proposition_data = props_test[str(row.dlg_idx)][str(row.prop_idx)]
        original_sent = proposition_data['proposition']
        assert row.prop.lower() == original_sent
        assert row.content_gold == proposition_data['a_thinks_true']
        sample.append((row.dlg_idx, row.prop_idx, row.turn_idx))
        
        before_to_after[(row.dlg_idx, row.prop_idx)] = (row.dlg_idx, row.prop_idx)

    else:
        props_list = props_test[str(row.dlg_idx)]
        item = [(idx, prop) for idx, prop in props_list.items() 
                if prop['turn_shared'] == row.turn_shared and prop['a_thinks_true'] == row.content_gold]
        prop_id, proposition_data = item[0]
        original_sent = proposition_data['proposition']
        assert row.prop.lower() == original_sent
        sample.append((row.dlg_idx, int(prop_id), row.turn_idx))
        
        before_to_after[(row.dlg_idx, row.prop_idx)] = (row.dlg_idx, int(prop_id))

sample = set(sample)
assert len(sample) == 100 - len(EXCLUDED)

# %%
sample_outputs = {task: {} for task in TASKS}

for (bot, task, version) in product(BOTS, TASKS, BOT_VERSIONS):
    if bot == 'q' and 'TF' in task:
        sample_outputs[task][(bot, version)] = 'NA'
        continue
        
    sample_outputs[task][(bot, version)] = {}
    for idx, (prediction, gold) in test_outputs[(bot, task, version)].items():
        dialogue_id, prop_id, sent_id, turn, _ = test_datapoints[(bot, task, version)][idx]
        if (dialogue_id, prop_id, turn) in sample:
            sample_outputs[task][(bot, version)][(dialogue_id, prop_id, turn)] = (prediction, gold)

    assert len(sample_outputs[task][(bot, version)]) == 100 - len(EXCLUDED)

# %%
def acc(outputs):
    if outputs == 'NA':
        return '-'
    return 100*np.mean([x==y for (x, y) in outputs.values()])

table = table_df.copy()

for (bot, version) in product(BOTS, BOT_VERSIONS):
    values = np.array([acc(sample_outputs[task][(bot, version)]) for task in table.columns])
    new_row = pd.DataFrame([values], index=[bot + ', ' + version], columns=table.columns)
    table = pd.concat([table, new_row])

# %%
table
# Out:
#               TFxPS       TF                 PS             PxTSFS
# human        91.844  94.3262            97.5177            96.0993
# a, RL-DIV   52.1277  65.9574            74.4681            65.9574
# a, SL            50  72.3404            73.4043            68.0851
# a, ICCV-RL  52.1277  71.2766            77.6596            67.0213
# q, RL-DIV         -        -  75.53191489361703  62.76595744680851
# q, SL             -        -   79.7872340425532   70.2127659574468
# q, ICCV-RL        -        -  75.53191489361703  68.08510638297872

# %%
print(table.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} &    TFxPS &       TF &                 PS &             PxTSFS \\
# \midrule
# human      &   91.844 &  94.3262 &            97.5177 &            96.0993 \\
# a, RL-DIV  &  52.1277 &  65.9574 &            74.4681 &            65.9574 \\
# a, SL      &       50 &  72.3404 &            73.4043 &            68.0851 \\
# a, ICCV-RL &  52.1277 &  71.2766 &            77.6596 &            67.0213 \\
# q, RL-DIV  &        - &        - &  75.53191489361703 &  62.76595744680851 \\
# q, SL      &        - &        - &   79.7872340425532 &   70.2127659574468 \\
# q, ICCV-RL &        - &        - &  75.53191489361703 &  68.08510638297872 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Making sure that datapoints are the same

# %%
sent_encoder = pickle.load(open('data/embeddings/embeddings_paraphrase-mpnet-base-v2.p', 'rb'))

# %% [markdown]
# We checked above that datapoints are the same across experiments, as they should be, so we'll just check one of them now:

# %%
data, _ = ev.get_data('a', 'TFxPS', 'none', PATH_OUTPUTS, split=SPLIT, bot_version='RL-DIV', epoch=0)

info_to_id = {v[:-1]:k for k, v in test_datapoints[('a', 'TFxPS', 'RL-DIV')].items()}
assert len(info_to_id) == len(test_datapoints[('a', 'TFxPS', 'RL-DIV')])

# %% [markdown]
# Compare with proposition dataset and the embeddings:

# %%
for _, row in annot_df.iterrows():
    
    # dialogue id and proposition id on the human results csv
    if (row.dlg_idx, row.prop_idx) in before_to_after:
        # dialogue id and proposition id to which they correspond on the final test set
        d_idx, p_idx = before_to_after[(row.dlg_idx, row.prop_idx)]
        
        before_sentence = row.prop
        after_sentence = props_test[str(d_idx)][str(p_idx)]['proposition']
        # confirm that the proposition used in the human eval is exactly the same as in the test set
        assert before_sentence.lower() == after_sentence
        
        # retrieve the sentence id on the loaded data
        sent_id = [s for (d, p, s, _), v in info_to_id.items() if d == d_idx and p == p_idx]
        # repetitions on different turns occur, but sentence id is unique
        assert len(set(sent_id)) == 1
        sent_id = sent_id[0]
        
        embedding = data.id2sent[sent_id]
        # ensure that it's the same as the one in the embeddings
        assert np.array_equal(embedding, sent_encoder[after_sentence])
